# %%
keras.layers.Conv2D(10, kernel_size = (3, 3), activtion = 'relu',
                    padding = 'same', strides = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-741edc42be6b> in <module>
# ----> 1 keras.layers.Conv2D(10, kernel_size = (3, 3), activtion = 'relu',
#       2                     padding = 'same', strides = 1)
#
# NameError: name 'keras' is not defined
